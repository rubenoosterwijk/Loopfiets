# %% [markdown]
# Bedankt https://scikit-learn.org/stable/auto_examples/classification/plot_digits_classification.html voor de code

# %% [markdown]
# ## Load libraries

# %%
import matplotlib.pyplot as plt
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
# from tensorflow.keras import layers, Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("dataset_annotations.txt", header=None)
df = df.rename(columns={0: "x1",
                   1: "y1",
                   2: "x2",
                   3: "y2",
                   4: "x3",
                   5: "y3",
                   6: "x4",
                   7: "y4",
                   8: "label",
                   9: "image_filename"}
               )

filelist = df.image_filename

df = df.set_index("image_filename")
df
# filelist
# Out:
#                            x1          y1          x2          y2          x3  \
# image_filename
# roadmark_0001.jpg  321.964233  456.406830  433.777863  335.275360  344.327148
# roadmark_0002.jpg  313.977539  453.744598  433.777863  329.950928  350.500000
# roadmark_0003.jpg  307.321960  449.751251  429.784515  325.957581  352.969147
# roadmark_0004.jpg  299.335266  452.413483  431.115631  323.295349  359.141968
# roadmark_0005.jpg  295.341919  461.731293  431.115631  316.639771  362.845673
# ...                       ...         ...         ...         ...         ...
# roadmark_1439.jpg  239.859268  269.149872  321.323792  296.609833  316.448273
# roadmark_1440.jpg  151.072083  216.975967  269.149872  227.044617  346.620697
# roadmark_1441.jpg   98.898170  164.802063  199.584671  147.410751  336.275848
# roadmark_1442.jpg  148.326080  207.822647  243.520599  197.753998  327.655182
# roadmark_1443.jpg   24.756292  118.120140  171.209381   92.490845  356.965515
#
# ...

# %%
# group = df.groupby('label')
labels = df.label.unique()
labels
# Out:
# array(['stop', 'leftturn', 'rightturn', 'rail', '35', 'forward', 'bike',
#        '40', 'ped', 'xing', 'diamond', 'car', 'pool', 'lane', 'keep',
#        'clear', '25', 'X-crossing', 'forward&right', 'speed', 'hump',
#        '30', 'slow', 'school', 'stripe', 'forward&left', 'yield'],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image
def greyScale(image, dir):
    loc = "Images/" + image
    img =Image.open(loc).convert('L')
    path = dir + "/" + image
    img.save(path)

x = greyScale(filelist[8], "Grey")

# %%
from PIL import Image
imggrey = mpimg.imread('Grey/roadmark_0001.jpg')
print(imggrey)

imgplot = plt.imshow(imggrey, cmap='gray', vmin=0, vmax=255)
# Out:
# [[27 27 27 ... 17 14 14]
#  [27 27 27 ... 12 11 11]
#  [29 29 29 ...  7  6  7]
#  ...
#  [ 5  5  5 ...  4  4  4]
#  [ 5  5  5 ...  4  4  4]
#  [ 5  5  5 ...  4  4  4]]

# %%
df = df.iloc[0]

# %%
x1,x2,x3,x4 = df.x1 , df.x2, df.x3 , df.x4

y1,y2,y3,y4 = df.y1 , df.y2, df.y3 , df.y4


top_left_x = min([x1,x2,x3,x4])
top_left_y = min([y1,y2,y3,y4])
bot_right_x = max([x1,x2,x3,x4])
bot_right_y = max([y1,y2,y3,y4])

print(top_left_x)
# Out:
# 321.964233

# %%
from PIL import Image

imageObj = cv2.imread("Grey/")
# gray = cv2.cvtColor(imageObj, cv2.COLOR_BGR2GRAY)
imageObj[top_left_y:bot_right_y, top_left_x:bot_right_x]

plt.imshow(cropped__img)
plt.title('my picture')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-577289be95b3> in <module>
#       3 imageObj = cv2.imread("Grey/roadmark_0001.jpg")
#       4 # gray = cv2.cvtColor(imageObj, cv2.COLOR_BGR2GRAY)
# ----> 5 crop = imageObj[top_left_y:bot_right_y, top_left_x:bot_right_x]
#       6
#       7 plt.imshow(crop)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
x1,x2,x3,x4 = df['x1'], df['x2'],df['x3'],df['x4']

y1,y2,y3,y4 = df['y1'], df['y2'],df['y3'],df['y4']

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

im = mpimg.imread('Grey/roadmark_0009.jpg')

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(im, cmap='gray', vmin=0, vmax=255)
# Create a Rectangle patch
rect = patches.Rectangle((50, 100), 40, 30, linewidth=1, edgecolor='r', facecolor='none')

x=[321.964233 ,433.777863 ,344.327148,317.166656]
y=[456.406830, 335.275360, 344.327148,317.166656]

for i in range(0, len(x), 2):
    plt.plot(x[i:i+2], y[i:i+2], 'ro-')

plt.plot()


plt.show()

# %%
from PIL import Image

imageObj = Image.open("Images/roadmark_0001.jpg")
imageObj
# cropped = imageObj.crop((row.x1, row.y1, row.x4, row.y4))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x173589AF550>

# %%
img_folder=r'Images/'
saved_location = "Cropped"


for file in os.listdir(os.path.join(img_folder)):
    print(file)
    row = df.loc[file]
    print(row)
    print(row.x1)

    image_path= os.path.join(img_folder, file)
    print(image_path)
    imageObj = Image.open(image_path)
    cropped = imageObj.crop((row.x1, row.y1, row.x4, row.y4))
    cropped.save(file)
    # image= cv2.imread(image_path, cv2.COLOR_BGR2RGB)
    # image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
    # image=np.array(image)
    # image = image.astype('float32')
    # image /= 255
    # img_data_array.append(image)
    # class_name.append(dir1)
    # return img_data_array, class_name
# Out:
# roadmark_0001.jpg
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'roadmark_0001.jpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
digits = datasets.load_digits()
type(digits)

# %% [markdown]
# ## Show data

# %%
digits['images']
type(digits)

# %%
digits['target'][0]
type(digits)

# %% [markdown]
# ## Show sample images

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title('Training: %i' % label)

# %% [markdown]
# ## Data manipulation

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

# %%
#check
print(digits['images'][0].shape)
print(data[0].shape)
print(data.shape)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data, digits.target, test_size=0.5, shuffle=False)

# %%
y_train[0]

# %% [markdown]
# ## Train en evaluate model

# %%
clf = svm.SVC(gamma=0.001)

# %%
clf.fit(X_train, y_train)

# %%
predicted = clf.predict(X_test)

# %%
accuracy_score(y_test, predicted)

# %% [markdown]
# ## Confusion matrix

# %%
disp = metrics.plot_confusion_matrix(clf, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
